# %% [markdown]
# <a href="https://colab.research.google.com/github/Avanlant/Analytics-school/blob/HW2/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание 1**
#
# ---

# %%
#pip install pandas
#pip install numpy
import numpy as np
import pandas as pd
df = pd.read_excel('Реестр_выполненных_рейсов_за_период.xlsx')
df.columns = df.iloc[0]
df = df.drop(0).reset_index(drop=True)
df = df.drop(11268).reset_index(drop=True)
df = df.drop(11268).reset_index(drop=True)
df = df.drop(11268).reset_index(drop=True)
df.dropna(how='all', axis=1, inplace=True)
df.reset_index().tail()
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 0      index В/П  № рейса Код АП       Маршрут     Борт     Время рейса план  \
# 11263  11263   В  FV 6587    SCW     СЫКТЫВКАР  RA89142  2025-01-31 23:35:00
# 11264  11264   В  FV 6001    IKT       ИРКУТСК  RA73218  2025-01-31 23:00:00
# 11265  11265   В  FV 6451    TJM        ТЮМЕНЬ  RA73214  2025-01-31 23:40:00
# 11266  11266   В  DP  515    SVX  ЕКАТЕРИНБУРГ  RA73245  2025-01-31 23:45:00
# 11267  11267   В  FV 6161    VKO       ВНУКОВО  RA89062  2025-01-31 23:55:00
#
# 0         Actual data time          ONB and OFB Компоновка  ... Кл.1 Кл.2  \
# 11263  2025-01-31 23:42:00  2025-01-31 23:29:00      W5Y95  ...    0    5
# 11264  2025-01-31 23:49:00  2025-01-31 23:21:00       Y189  ...    0    0
# ...

# %% [markdown]
# **Задание 2**
#
# ---

# %%
Info = "Информация о датасете"  # @param ['Информация о датасете', 'Статистика', 'Размерность даннных', 'Пропущенные значения']
if Info == "Информация о датасете":
    print ('\033[1m'+"--- Информация о датасете ---"+'\033[0m')
    df.info()
elif Info == "Статистика":
    print ('\033[1m'+"\n--- Статистика ---"+'\033[0m')
    print (df.describe())
elif Info == "Размерность даннных":
    print ('\033[1m'+"\n--- Размерность данных ---"+'\033[0m')
    print (f"Строк: {df.shape[0]}, Столбцов: {df.shape[1]}")
elif Info == "Пропущенные значения":
    print ('\033[1m'+"\n--- Пропущенные значения ---"+'\033[0m')
    print (df.isna().sum())
# Out:
# --- Информация о датасете ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11268 entries, 0 to 11267
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   В/П                   11268 non-null  object
#  1   № рейса               11268 non-null  object
#  2   Код АП                11268 non-null  object
#  3   Маршрут               11241 non-null  object
#  4   Борт                  11268 non-null  object
#  5   Время рейса план      11268 non-null  object
#  6   Actual data time      11268 non-null  object
#  7   ONB and OFB           11268 non-null  object
#  8   Компоновка            11252 non-null  object
#  9   Вместимость           11268 non-null  object
#  10  Обслужено пассажиров  11266 non-null  object
#  11  Взр                   11268 non-null  object
#  12  Дети                  11268 non-null  object
#  13  До 2-лет              11268 non-null  object
# ...

# %% [markdown]
# **Задание 3**
#
# ---

# %%
df.per = df['Код АП'].value_counts(normalize=True).mul(100).round(2).rename('Процент(%)')
df.per.head(10).reset_index()
# Out:
#   Код АП  Процент(%)
# 0    SVO       15.11
# 1    VKO        9.30
# 2    KGD        5.93
# 3    AER        3.85
# 4    KZN        3.25
# 5    MMK        2.90
# 6    SVX        2.79
# 7    ARH        2.78
# 8    KUF        2.41
# 9    UFA        2.17

# %% [markdown]
# **Задание 4**
#
# ---

# %%
df.perdom = df.loc[df['Направление'] == 'Domestic', 'Код АП'].value_counts(normalize=True).mul(100).round(2).rename('Процент(%)')
df.perdom.head(10).reset_index()
# Out:
#   Код АП  Процент(%)
# 0    SVO       18.18
# 1    VKO       11.18
# 2    KGD        7.13
# 3    AER        4.63
# 4    KZN        3.91
# 5    MMK        3.49
# 6    SVX        3.35
# 7    ARH        3.34
# 8    KUF        2.89
# 9    UFA        2.61

# %% [markdown]
# **Задание 5**
#
# ---

# %%
select = "Domestic" # @param ["Domestic", "International"]
topcount = df.loc[df['Направление'] == select, 'Код АП'].value_counts().reset_index()
topcount.columns = ['Код АП', 'Кол-во рейсов']
top = topcount['Кол-во рейсов'].max()
pop = topcount[topcount['Кол-во рейсов'] == top]['Код АП']
print ('\033[1m'+'Самый популярный маршрут по каждому из направлений', select, ':' +'\033[0m', ','.join(pop))
# Out:
# Самый популярный маршрут по каждому из направлений Domestic : SVO

# %% [markdown]
# **Задание 6 и 7**
#
# ---

# %%
Airport = "SLY"  # @param ['AER', 'ALA', 'ARH', 'ASF', 'AUH', 'AYT', 'BAX', 'BEG', 'BHK','BKK', 'BUS', 'CEE', 'CEK', 'CMB', 'CSY', 'DME', 'DWC', 'DXB','DYU', 'EVN', 'FEG', 'FRU', 'GME', 'GOJ', 'GRV', 'GSV', 'GYD','HKT', 'HRG', 'HTA', 'IAR', 'IJK', 'IKT', 'IST', 'IWA', 'KEJ','KGD', 'KHV', 'KJA', 'KLF', 'KMW', 'KRO', 'KSQ', 'KUF', 'KVK','KVX', 'KZN', 'LBD', 'LED', 'MCX', 'MMK', 'MQF', 'MRV', 'MSQ','NAL', 'NBC', 'NJC', 'NMA', 'NNM', 'NOJ', 'NOZ', 'NQZ', 'NSK','NUX', 'NYM', 'OGZ', 'OMS', 'OSS', 'OSW', 'OVB', 'PEE', 'PEK','PEZ', 'PVG', 'REN', 'RGK', 'RMZ', 'SAW', 'SCW', 'SGC', 'SKD','SLY', 'SSH', 'STW', 'SVO', 'SVX', 'TAS', 'TBS', 'TBW', 'TFU','TJM', 'TMJ', 'TOF', 'UCT', 'UFA', 'UGC', 'ULV', 'VGD', 'VKO','VOG', 'YKS', 'ZIA']
Category = "C"  # @param ['C', 'G', 'J', 'S']
df1 = df.dropna().copy()
df1["Baggage Weight"] = df1["Baggage Weight"].astype(int)
Filtered = df1.loc[((df['Код АП'] == Airport) & (df1['Катег'] == Category))].sort_values(by='Baggage Weight', ascending=[False])
Filtered
# Out:
# 0    В/П  № рейса Код АП   Маршрут     Борт     Время рейса план  \
# 9511   В  YC 9716    SLY  САЛЕХАРД  RA67219  2025-01-26 14:00:00
# 8941   П  YC 9715    SLY  САЛЕХАРД    67219  2025-01-24 19:00:00
#
# 0        Actual data time          ONB and OFB Компоновка Вместимость  ...  \
# 9511  2025-01-26 14:04:00  2025-01-26 14:02:00        C14          19  ...
# 8941  2025-01-24 19:30:00  2025-01-24 19:34:00         14          19  ...
#
# 0    Кл.1 Кл.2 Кл.3 МВМ, тонн Тип ВС АВК  Направление Катег Baggage Weight  \
# 9511    0    0    5     24.04    CR2    1    Domestic     C            180
# 8941    0    6    0     24.04    CR2    1    Domestic     C             40
#
# 0    Spot Number
# 9511         262
# 8941         262
#
# [2 rows x 24 columns]

# %% [markdown]
# **Задание 8**
#
# ---

# %%
grouped = df.groupby(['Направление','Тип ВС'])
aggregated = grouped.agg({
    'Вместимость': 'mean',
    'МВМ, тонн': 'mean'
})
print(aggregated)
# Out:
# 0                    Вместимость   МВМ, тонн
# Направление   Тип ВС
# Domestic      319     128.208817   70.077146
#               320     158.302013    76.40604
#               321     215.638298   89.170213
#               32A     151.274538        75.5
#               32B     189.848485   91.113636
#               32N     176.170732   75.213415
#               32Q     237.549708   93.520468
#               332      361.47619       233.0
#               333     298.692308  233.365385
#               735          126.0       56.85
#               73G          140.0       70.08
#               73H     188.229361   76.871667
#               73W          148.0   67.269776
#               77W     420.333333     325.074
#               789          290.0     250.836
#               A26           40.0        24.0
#               CR1           50.0       24.04
#               CR2           49.5   24.034194
#               E90          110.0        50.3
# ...
